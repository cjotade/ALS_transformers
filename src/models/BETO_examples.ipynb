# %%
def create_model_inputs(sentence, tokenizer, T=20):
    #Step 1: Tokenize
    tokens = tokenizer.tokenize(sentence)
    #Step 2: Add [CLS] and [SEP]
    tokens = ['[CLS]'] + tokens + ['[SEP]']
    #Step 3: Pad tokens
    padded_tokens = tokens + ['[PAD]' for _ in range(T - len(tokens))]
    attn_mask = [1 if token != '[PAD]' else 0 for token in padded_tokens]
    #Step 4: Segment ids
    seg_ids = [0 for _ in range(len(padded_tokens))] #Optional!
    #Step 5: Get BERT vocabulary index for each token
    token_ids = tokenizer.convert_tokens_to_ids(padded_tokens)

    #Converting everything to torch tensors before feeding them to bert_model
    token_ids = torch.tensor(token_ids).unsqueeze(0) #Shape : [1, 12]
    attn_mask = torch.tensor(attn_mask).unsqueeze(0) #Shape : [1, 12]
    seg_ids   = torch.tensor(seg_ids).unsqueeze(0) #Shape : [1, 12]
    
    return token_ids, attn_mask, seg_ids, padded_tokens

def predict_masks(padded_tokens, hidden_reps, tokenizer):
    predicted_tokens = []
    for i, midx in enumerate(np.where(np.array(padded_tokens) == '[MASK]')[0]):
        idxs = torch.argsort(hidden_reps[0,midx], descending=True)
        predicted_token = tokenizer.convert_ids_to_tokens(idxs[:5])
        print(f'MASK {i}:', predicted_token)
        predicted_tokens.append(predicted_token)
    return predicted_tokens

# %%
prompt_text = "Hello "
src_text = [f">>es<< {prompt_text}"]

encoded_prompt = tokenizer.prepare_translation_batch(src_text, return_tensors="pt")
#encoded_prompt = tokenizer.encode(src_text, add_special_tokens=False, return_tensors="pt", add_space_before_punct_symbol=True)
encoded_prompt
# Out:
# {'input_ids': tensor([[  16, 4708,    0]]), 'attention_mask': tensor([[1, 1, 1]])}

# %%
output_sequences = model.generate(encoded_prompt["input_ids"])
output_sequences
# Out:
# tensor([[65000,  9261,     3]])

# %%
generated_sequences = []
for _, generated_sequence in enumerate(output_sequences):
    generated_sequence = generated_sequence.tolist()

    if not isinstance(generated_sequence, list):
        generated_sequence = [generated_sequence]

    # Decode text
    text = tokenizer.decode(generated_sequence, skip_special_tokens=True, clean_up_tokenization_spaces=True)

    # Remove all text after the stop token
    #text = text[: text.find(self.args.stop_token) if self.args.stop_token else None]

    # Add the prompt at the beginning of the sequence. Remove the excess text that was used for pre-processing
    total_sequence = (
        prompt_text + text[len(tokenizer.decode(encoded_prompt[0], clean_up_tokenization_spaces=True)) :]
    )

    generated_sequences.append(total_sequence)
generated_sequences
# Out:
# Hola.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-495db4aac22e> in <module>
#      15     print(text)
#      16     total_sequence = (
# ---> 17         prompt_text + text[len(tokenizer.decode(encoded_prompt[0], clean_up_tokenization_spaces=True)) :]
#      18     )
#      19
#
# ~/Environments/als-env/lib/python3.7/site-packages/transformers/tokenization_utils_base.py in __getitem__(self, item)
#     174         else:
#     175             raise KeyError(
# --> 176                 "Indexing with integers (to access backend Encoding for a given batch index) "
#     177                 "is not available when using Python based tokenizers"
#     178             )
#
# KeyError: 'Indexing with integers (to access backend Encoding for a given batch index) is not available when using Python based tokenizers'

# %%
tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
tgt_text
# Out:
# ['Hola.']

# %%
translated.shape
# Out:
# torch.Size([1, 156])

# %%
from transformers import MarianMTModel, MarianTokenizer
src_text = [
    '>>fr<< this is a sentence in english that we want to translate to french',
    '>>pt<< This should go to portuguese',
    '>>es<< And this to Spanish'
]

model_name = 'Helsinki-NLP/opus-mt-en-ROMANCE'
tokenizer = MarianTokenizer.from_pretrained(model_name)
print(tokenizer.supported_language_codes)
model = MarianMTModel.from_pretrained(model_name)
# Out:
# ['>>fr<<', '>>es<<', '>>it<<', '>>pt<<', '>>pt_br<<', '>>ro<<', '>>ca<<', '>>gl<<', '>>pt_BR<<', '>>la<<', '>>wa<<', '>>fur<<', '>>oc<<', '>>fr_CA<<', '>>sc<<', '>>es_ES<<', '>>es_MX<<', '>>es_AR<<', '>>es_PR<<', '>>es_UY<<', '>>es_CL<<', '>>es_CO<<', '>>es_CR<<', '>>es_GT<<', '>>es_HN<<', '>>es_NI<<', '>>es_PA<<', '>>es_PE<<', '>>es_VE<<', '>>es_DO<<', '>>es_EC<<', '>>es_SV<<', '>>an<<', '>>pt_PT<<', '>>frp<<', '>>lad<<', '>>vec<<', '>>fr_FR<<', '>>co<<', '>>it_IT<<', '>>lld<<', '>>lij<<', '>>lmo<<', '>>nap<<', '>>rm<<', '>>scn<<', '>>mwl<<']

# %%
tgt_text
# Out:
# ["c'est une phrase en anglais que nous voulons traduire en français",
#  'Isto deve ir para o português.',
#  'Y esto al español']

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

class GPT2:
    def __init__(self):
        self.tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        self.model = GPT2LMHeadModel.from_pretrained('gpt2').to('cuda')
        #self.model = GPT2Model.from_pretrained('gpt2')
        self.model.eval()

    def create_model_inputs(self, sentence):
        token_sentence = self.tokenizer.encode(sentence, add_special_tokens=True)
        input_ids = torch.tensor(token_sentence).unsqueeze(0).to('cuda')  # Batch size 1
        return input_ids.to('cuda')

    def predict_tokens(self, sentence, width=5):
        input_ids = self.create_model_inputs(sentence).to('cuda')
        hidden_reps = self.model(input_ids)[0].to('cuda')
        idxs = torch.argsort(hidden_reps[0,-1], descending=True).to('cuda')
        predicted_token = self.tokenizer.convert_ids_to_tokens(idxs[:width])
        predicted_token = [pred[1:]  for pred in predicted_token]
        return predicted_token

    def expand_predictions(self, sentence, sentences_tree=[], width=3, length=3):
        predicted_tokens = self.predict_tokens(sentence, width=width)
        sentences = [sentence + pred_token + " " for pred_token in predicted_tokens]
        for sent in sentences:
            if length > 0:
                self.expand_predictions(sent, sentences_tree=sentences_tree, width=width, length=length-1)
            else:
                sentences_tree.append(sent)
                
        return sentences_tree.copy()

    def run(self, sentence):
        predicted_token = self.predict(sentence, width=5)
        return predicted_token
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.

# %%
model = GPT2()
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.attn.masked_bias', 'h.1.attn.masked_bias', 'h.2.attn.masked_bias', 'h.3.attn.masked_bias', 'h.4.attn.masked_bias', 'h.5.attn.masked_bias', 'h.6.attn.masked_bias', 'h.7.attn.masked_bias', 'h.8.attn.masked_bias', 'h.9.attn.masked_bias', 'h.10.attn.masked_bias', 'h.11.attn.masked_bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
sentence = "Before boarding your rocket to Mars, remember to pack these items "
#sentence = "My dear "
model.expand_predictions(sentence, [], width=2, length=10)
# Out:
# ['Before boarding your rocket to Mars, remember to pack these items with your gear         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear        and ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear       and take ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear       and keep ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear      and keep them ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear      and keep your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear      and take them ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear      and take care ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and keep them in ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and keep them on ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and keep your rocket ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and keep your gear ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and take them to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and take them with ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and take care of ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear     and take care not ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep them in your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep them in a ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep them safe  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep them safe from ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep your rocket safe ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep your rocket in ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep your gear in ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and keep your gear on ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take them to the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take them to your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take them with you ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take them with your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take care of your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take care of them ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take care not to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear    and take care not let ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them in your backpack ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them in your pocket ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them in a safe ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them in a secure ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them safe   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them safe  from ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them safe from the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep them safe from any ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your rocket safe  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your rocket safe from ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your rocket in a ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your rocket in the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your gear in a ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your gear in your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your gear on the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and keep your gear on your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them to the landing ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them to the nearest ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them to your destination ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them to your landing ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them with you  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them with you to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them with your crew ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take them with your spacecraft ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care of your gear ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care of your rocket ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care of them  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care of them as ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care not to get ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care not to over ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care not let your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear   and take care not let the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket    booster ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket   booster  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket   booster  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket  booster   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket  booster   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket  booster   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket  booster   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your rocket booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and your supplies     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be ready to go ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be ready to launch ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be ready for the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be ready for your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be able to get ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be able to take ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be able ta get ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll be able ta be ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get to the landing ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get to the next ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get to see the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get to see what ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get a good look ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get a good idea ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get a chance to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you ll get a chance at ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be ready to go ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be ready to launch ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be ready for the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be ready for your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be able to get ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be able to use ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be able take your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will be able take it ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have a chance to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have a chance of ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have a very good ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have a very nice ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have the chance to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have the chance of ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have the opportunity to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear  and you will have the opportunity for ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket     booster ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket    booster  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket    booster  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket   booster   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket   booster  pack ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket   booster pack  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket   booster pack  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster   pack ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster  pack  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster  pack  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster pack   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster pack   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster pack   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket  booster pack   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your rocket booster     ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and your supplies      ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to go    ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get ready for the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get ready for your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get ready to go ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get ready to launch ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get out there  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get out there and ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get out of there ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready to get out of the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the journey   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the journey  to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the journey to Mars ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the journey to the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the next mission  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the next mission  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the next step  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for the next step  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a long journey  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a long journey to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a long  journey ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a long   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a few minutes of ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a few minutes to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a few days of ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get ready for a few days to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for the journey  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for the journey to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for the mission  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for the mission to ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for launch   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for launch   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for launch   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready for launch   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to go   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to go  in ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to go in the ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to go in a ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to launch   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to launch  your ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to launch your rocket ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them ready to launch your spacecraft ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the landing site  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the landing site before ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the landing pad  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the landing pad before ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the right place  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the right place before ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the right location  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to the right location before ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your destination   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your destination  before ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your destination before you ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your destination before they ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your home   ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your home  base ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your home base  ',
#  'Before boarding your rocket to Mars, remember to pack these items with your gear and get them to your home base before ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
#  'Before boarding your rocket to Mars, remember to pack these items with your belongings         ',
# ...
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack  and some extra supplies  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack  and some extra supplies to ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare rocket booster  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare rocket booster  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare rocket pack with ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare rocket pack for ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare fuel tank  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare fuel tank  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare fuel pack  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a spare fuel pack  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few extra batteries  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few extra batteries  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few extra pieces of ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few extra pieces to ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few other items  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few other items to ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few other essentials  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and a few other essentials  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare fuel   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare fuel   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare fuel   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare fuel   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare batteries   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare batteries   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare batteries   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some spare batteries   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies   to ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies  to keep ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies  to help ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies to keep you ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies to keep your ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies to get you ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare rocket pack and some supplies to get your ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your own     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket     ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket    and ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket   and a ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket   and the ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket  and a spare ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket  and a few ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket  and your rocket ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket  and your parachute ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and a spare rocket ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and a spare piece ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and a few extra ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and a few spare ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and your rocket booster ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and your rocket s ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and your parachute  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of your rocket and your parachute  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper      ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper     and ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper    and a ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper    and write ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper   and a few ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper   and a pencil ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper   and write down ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper   and write it ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and a few other ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and a few extra ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and a pencil  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and a pencil  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and an extra piece ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and an extra copy ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and an envelope  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper  and an envelope with ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a few extra pieces ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a few extra batteries ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a few other items ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a few other essentials ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a pencil   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a pencil   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a pencil   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and a pencil   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an extra piece of ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an extra piece for ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an extra copy of ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an extra copy  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an envelope   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an envelope  with ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an envelope with your ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece of paper and an envelope with the ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your own    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket   and ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket  and a ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket  and your ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket and a spare ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket and a few ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket and your rocket ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of your rocket and your parachute ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket   s ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket  s you ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket  s  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket s nder  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket s nder and ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket s ding  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the rocket s ding  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft s ding  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft s ding y ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft s nder  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft s nder you ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft  s  ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft  s you ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft   s ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece  of the spacecraft    ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your own   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your own   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your own   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your own   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your rocket   ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your rocket  and ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your rocket and a ',
#  'Before boarding your rocket to Mars, remember to pack these items with a spare piece   of your rocket and your ',
#  ...]

# %% [markdown]
# # BETO

# %%
# Fist install the library and download the models from github

#!pip install transformers
#!wget https://users.dcc.uchile.cl/~jperez/beto/cased_2M/pytorch_weights.tar.gz 
#!wget https://users.dcc.uchile.cl/~jperez/beto/cased_2M/vocab.txt 
#!wget https://users.dcc.uchile.cl/~jperez/beto/cased_2M/config.json 
#!tar -xzvf pytorch_weights.tar.gz
#!mv config.json pytorch/.
#!mv vocab.txt pytorch/.

# %%
# import the necessary

import torch
import numpy as np
from transformers import BertForMaskedLM, BertTokenizer

# %%
# create the tokenizer and the model

tokenizer = BertTokenizer.from_pretrained("../../weights/beto/", do_lower_case=False)
model = BertForMaskedLM.from_pretrained("../../weights/beto/")
model.eval()
# Out:
# Some weights of the model checkpoint at ../../weights/beto/ were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at ../../weights/beto/ and are newly initialized: ['cls.predictions.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(31002, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=31002, bias=True)
#     )
#   )
# )

# %%
num_return_sequences = 5
length = 10
temperature = 1.0
k = 0
p = 0.9
repetition_penalty = 2.0

# Encode
prompt_text = "Me gustaria comer un"
encoded_prompt = tokenizer.encode(prompt_text, add_special_tokens=False, return_tensors="pt", add_space_before_punct_symbol=True)
input_ids = encoded_prompt

# Generate
output_sequences = model.generate(
            input_ids=input_ids,
            max_length=length + len(encoded_prompt[0]),
            temperature=temperature,
            top_k=k,
            top_p=p,
            repetition_penalty=repetition_penalty,
            do_sample=True,
            num_return_sequences=num_return_sequences,
        )

if len(output_sequences.shape) > 2:
            output_sequences.squeeze_()
        
# Decode
for _, generated_sequence in enumerate(output_sequences):
    generated_sequence = generated_sequence.tolist()

    # Decode text
    text = tokenizer.decode(generated_sequence, clean_up_tokenization_spaces=True)

    # Remove all text after the stop token
    #text = text[: text.find(tokenizer.stop_token) if tokenizer.stop_token else None]

    # Add the prompt at the beginning of the sequence. Remove the excess text that was used for pre-processing
    total_sequence = (
        prompt_text + text[len(tokenizer.decode(encoded_prompt[0], clean_up_tokenization_spaces=True)) :]
    )

    print(total_sequence)
# Out:
# Me gustaria comer un día y cena hasta quedaraduraiadolosiosia
# Me gustaria comer un bien. saber a es eres, alguien que sabe
# Me gustaria comer un recuerdo recordar recuerdos, siempre recuerda amigo alguien ver algo
# Me gustaria comer un martes y dos, me gustaría así como hoy día
# Me gustaria comer un martesteblete para yo. Quieronr

# %%
def create_model_inputs(sentence, tokenizer, T=20):
    #Step 1: Tokenize
    tokens = tokenizer.tokenize(sentence)
    #Step 2: Add [CLS] and [SEP]
    tokens = ['[CLS]'] + tokens + ['[SEP]']
    #Step 3: Pad tokens
    padded_tokens = tokens + ['[PAD]' for _ in range(T - len(tokens))]
    attn_mask = [1 if token != '[PAD]' else 0 for token in padded_tokens]
    #Step 4: Segment ids
    seg_ids = [0 for _ in range(len(padded_tokens))] #Optional!
    #Step 5: Get BERT vocabulary index for each token
    token_ids = tokenizer.convert_tokens_to_ids(padded_tokens)

    #Converting everything to torch tensors before feeding them to bert_model
    token_ids = torch.tensor(token_ids).unsqueeze(0) #Shape : [1, 12]
    attn_mask = torch.tensor(attn_mask).unsqueeze(0) #Shape : [1, 12]
    seg_ids   = torch.tensor(seg_ids).unsqueeze(0) #Shape : [1, 12]
    
    return token_ids, attn_mask, seg_ids, padded_tokens

def predict_masks(padded_tokens, hidden_reps, tokenizer):
    predicted_tokens = []
    for i, midx in enumerate(np.where(np.array(padded_tokens) == '[MASK]')[0]):
        idxs = torch.argsort(hidden_reps[0,midx], descending=True)
        predicted_token = tokenizer.convert_ids_to_tokens(idxs[:5])
        print(f'MASK {i}:', predicted_token)
        predicted_tokens.append(predicted_token)
    return predicted_tokens

# %%
#Specifying the max length
T = 12

#sentence = "[CLS] Para [MASK] los [MASK] de Chile, el ministro debe [MASK] de inmediato. [SEP]"
#sentence = "Tengo sed, dame un [MASK] de [MASK]"
sentence = "Me gustaria comer un [MASK]"

# Inputs
token_ids, attn_mask, seg_ids, padded_tokens = create_model_inputs(sentence, tokenizer, T)

#Feed them to bert
hidden_reps = model(token_ids, attention_mask=attn_mask, token_type_ids=seg_ids)[0]

predicted_tokens = predict_masks(padded_tokens, hidden_reps, tokenizer)
# Out:
# MASK 0: ['poco', 'huevo', '[UNK]', 'pollo', 'pastel']

# %%
hidden_reps
# Out:
# tensor([[[-5.1854, -4.7943, -7.0020,  ..., -1.2600, -5.5297, -1.4943],
#          [-7.3981, -4.6803, -6.7148,  ..., -2.3201, -6.3886,  2.7555],
#          [-4.7479, -3.5458, -6.6794,  ..., -3.9077, -4.5072,  1.3221],
#          ...,
#          [-3.6298, -2.5964, -4.8563,  ..., -3.5403, -4.3189, -3.0126],
#          [-4.3041, -3.7013, -6.3754,  ..., -3.4638, -5.4781, -3.3132],
#          [-5.4552, -5.1397, -9.1342,  ..., -4.9846, -8.0668, -5.2595]]],
#        grad_fn=<AddBackward0>)

# %%
hidden_reps
padded_tokens
# Out:
# ['[CLS]',
#  'Tengo',
#  'sed',
#  ',',
#  'dame',
#  'un',
#  '[MASK]',
#  'de',
#  '[MASK]',
#  '[SEP]',
#  '[PAD]',
#  '[PAD]']

# %%
sentence = "[CLS] Tengo sed, dame un vaso de [MASK] [SEP]"
print(tokenizer.convert_tokens_to_ids(tokenizer.tokenize(sentence)))
print(tokenizer.encode(sentence, add_special_tokens=False, return_tensors="pt", add_space_before_punct_symbol=True))
# Out:
# [4, 2190, 15077, 1017, 10574, 1049, 12986, 1008, 0, 5]
# tensor([[    4,  2190, 15077,  1017, 10574,  1049, 12986,  1008,     0,     5]])

# %%
model(token_ids, attention_mask=attn_mask, token_type_ids=seg_ids)[0][0, 1]
# Out:
# tensor([-6.1508, -7.5639, -5.4450,  ...,  1.7980, -5.7680, -0.5667],
#        grad_fn=<SelectBackward>)

# %%
torch.argsort(
    model(token_ids, attention_mask=attn_mask, token_type_ids=seg_ids)[0][0, 1], 
    descending=True)
# Out:
# tensor([ 2190,  1847,  4068,  ..., 28800,  8401, 30838])

# %%
predicted_tokens, idxs = predict_masks(padded_tokens, hidden_reps, tokenizer)
# Out:
# MASK 0: ['poco', 'vaso', 'trago', 'poquito', 'beso']
# MASK 1: ['agua', 'vino', 'leche', 'amor', 'lluvia']

# %% [markdown]
# # SCIBERT

# %%
from transformers import *

tokenizer = AutoTokenizer.from_pretrained('allenai/scibert_scivocab_uncased')
model = BertForMaskedLM.from_pretrained('allenai/scibert_scivocab_uncased')

# %%
import torch
import numpy as np

#Specifying the max length
T = 12

# Sentence
#sentence = 'Character-level modeling of [MASK] language text is [MASK], for several [MASK].'
#sentence = 'Prognosis may be essentially understood as the [MASK]' #the [MASK] of long-[MASK] predictions for a [MASK] indicator, made with the purpose'
sentence = 'The evaluation of these integrals, though, may be difficult and/or may require significant [MASK]'

# Inputs
token_ids, attn_mask, seg_ids, padded_tokens = create_model_inputs(sentence, tokenizer, T)

#Feed them to bert
hidden_reps = model(token_ids, attention_mask=attn_mask, token_type_ids=seg_ids)[0]

# %%
predicted_tokens = predict_masks(padded_tokens, hidden_reps, tokenizer)

# %% [markdown]
# ## Multiple

# %%
import torch
import numpy as np

#Specifying the max length
T = 100

# Sentence
#sentence = 'Character-level modeling of [MASK] language text is [MASK], for several [MASK].'
sentence = 'The evaluation of these integrals, though, may be difficult and/or may require significant [MASK]'

for _ in range(10):
    # Inputs
    token_ids, attn_mask, seg_ids, padded_tokens = create_model_inputs(sentence, tokenizer, T)

    #Feed them to bert
    hidden_reps = model(token_ids, attention_mask=attn_mask, token_type_ids=seg_ids)[0]

    for i, midx in enumerate(np.where(np.array(padded_tokens) == '[MASK]')[0]):
        idxs = torch.argsort(hidden_reps[0,midx], descending=True)
        predicted_token = tokenizer.convert_ids_to_tokens(idxs[:5])
        #print(f'MASK {i}:', predicted_token)
        sentence = sentence.split("[MASK]")[0] + predicted_token[0] + " [MASK]"
        print(sentence)
# Out:
# The evaluation of these integrals, though, may be difficult and/or may require significant . [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . . [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . . . [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . . . " [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . . . " . [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . . . " . " [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . . . " . " . [MASK]
# The evaluation of these integrals, though, may be difficult and/or may require significant . " . . . " . " . " [MASK]

# %% [markdown]
# # BERT

# %%
import torch
import numpy as np
from transformers import BertModel, BertTokenizer, BertForMaskedLM

#Creating instance of BertModel
bert_model = BertForMaskedLM.from_pretrained('bert-base-uncased')

#Creating intance of tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
#Specifying the max length
T = 20

# Sentence
sentence = 'Character-level modeling of [MASK] language text is [MASK], for several [MASK].'

# Inputs
token_ids, attn_mask, seg_ids, padded_tokens = create_model_inputs(sentence, tokenizer, T)

#Feed them to bert
hidden_reps = bert_model(token_ids, attention_mask=attn_mask, token_type_ids=seg_ids)[0]

# %%
predicted_tokens = predict_masks(padded_tokens, hidden_reps, tokenizer)

# %% [markdown]
# ## FINE TUNING

# %%
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer
import pandas as pd

class SSTDataset(Dataset):

    def __init__(self, filename, maxlen):

        #Store the contents of the file in a pandas dataframe
        self.df = pd.read_csv(filename, delimiter = '\t')

        #Initialize the BERT tokenizer
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

        self.maxlen = maxlen

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):

        #Selecting the sentence and label at the specified index in the data frame
        sentence = self.df.loc[index, 'sentence']
        label = self.df.loc[index, 'label']

        #Preprocessing the text to be suitable for BERT
        tokens = self.tokenizer.tokenize(sentence) #Tokenize the sentence
        tokens = ['[CLS]'] + tokens + ['[SEP]'] #Insering the CLS and SEP token in the beginning and end of the sentence
        if len(tokens) < self.maxlen:
            tokens = tokens + ['[PAD]' for _ in range(self.maxlen - len(tokens))] #Padding sentences
        else:
            tokens = tokens[:self.maxlen-1] + ['[SEP]'] #Prunning the list to be of specified max length

        tokens_ids = self.tokenizer.convert_tokens_to_ids(tokens) #Obtaining the indices of the tokens in the BERT Vocabulary
        tokens_ids_tensor = torch.tensor(tokens_ids) #Converting the list to a pytorch tensor

        #Obtaining the attention mask i.e a tensor containing 1s for no padded tokens and 0s for padded ones
        attn_mask = (tokens_ids_tensor != 0).long()

        return tokens_ids_tensor, attn_mask, label

# %%
from torch.utils.data import DataLoader

#Creating instances of training and validation set
train_set = SSTDataset(filename = 'DATA/trainDevTestTrees_PTB/trees/train.txt', maxlen = 30)
val_set = SSTDataset(filename = 'DATA/trainDevTestTrees_PTB/trees/dev.txt', maxlen = 30)

#Creating intsances of training and validation dataloaders
train_loader = DataLoader(train_set, batch_size = 64, num_workers = 5)
val_loader = DataLoader(val_set, batch_size = 64, num_workers = 5)

# %%
import torch
import torch.nn as nn
from transformers import BertModel

class SentimentClassifier(nn.Module):

    def __init__(self, freeze_bert = True):
        super(SentimentClassifier, self).__init__()
        #Instantiating BERT model object 
        self.bert_layer = BertModel.from_pretrained('bert-base-uncased')
        
        #Freeze bert layers
        if freeze_bert:
            for p in self.bert_layer.parameters():
                p.requires_grad = False
        
        #Classification layer
        self.cls_layer = nn.Linear(768, 1)

    def forward(self, seq, attn_masks):
        '''
        Inputs:
            -seq : Tensor of shape [B, T] containing token ids of sequences
            -attn_masks : Tensor of shape [B, T] containing attention masks to be used to avoid contibution of PAD tokens
        '''

        #Feeding the input to BERT model to obtain contextualized representations
        cont_reps, _ = self.bert_layer(seq, attention_mask = attn_masks)

        #Obtaining the representation of [CLS] head
        cls_rep = cont_reps[:, 0]

        #Feeding cls_rep to the classifier layer
        logits = self.cls_layer(cls_rep)

        return logits

# %%
net = SentimentClassifier(freeze_bert = True)

# %%
import torch.nn as nn
import torch.optim as optim

criterion = nn.BCEWithLogitsLoss()
opti = optim.Adam(net.parameters(), lr = 2e-5)

# %%
def train(net, criterion, opti, train_loader, val_loader, args):

    for ep in range(args.max_eps):
        
        for it, (seq, attn_masks, labels) in enumerate(train_loader):
            #Clear gradients
            opti.zero_grad()  
            #Converting these to cuda tensors
            seq, attn_masks, labels = seq.cuda(args.gpu), attn_masks.cuda(args.gpu), labels.cuda(args.gpu)

            #Obtaining the logits from the model
            logits = net(seq, attn_masks)

            #Computing loss
            loss = criterion(logits.squeeze(-1), labels.float())

            #Backpropagating the gradients
            loss.backward()

            #Optimization step
            opti.step()

            if (it + 1) % args.print_every == 0:
                acc = get_accuracy_from_logits(logits, labels)
                print("Iteration {} of epoch {} complete. Loss : {} Accuracy : {}".format(it+1, ep+1, loss.item(), acc))

# %%
class Arguments:
    def __init__(self, gpu=0, freeze_bert="store_true", maxlen=25, batch_size=32, lr=2e-5, print_every=100, max_eps=5):
        self.gpu = gpu
        self.freeze_bert = freeze_bert
        self.maxlen = maxlen
        self.batch_size = batch_size
        self.lr = lr
        self.print_every = print_every
        self.max_eps = max_eps

# %%
args = Arguments()

# %%
train(net, criterion, opti, train_loader, val_loader, args)
